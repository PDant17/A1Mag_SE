# %% [markdown]
# #### This notebook demonstrates the use of adversarial debiasing algorithm to learn a fair classifier.
# **DEF**: Adversarial machine learning is a machine learning method that aims to trick machine learning models by providing deceptive inputs.
#
# ![adversarial_threats_attacker.webp](data:image/webp;base64,...)
#
# Adversarial debiasing [1] is an in-processing technique that learns a classifier to maximize prediction accuracy and simultaneously reduce an adversary's ability to determine the protected attribute from the predictions. This approach leads to a fair classifier as the predictions cannot carry any group discrimination information that the adversary can exploit. We will see how to use this algorithm for learning models with and without fairness constraints and apply them on the Adult dataset.

# %%
pip install aif360
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aif360
#   Downloading aif360-0.5.0-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.2.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from aif360) (3.7.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.10.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->aif360) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->aif360) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->aif360) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->aif360) (3.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->aif360) (1.16.0)
# Installing collected packages: aif360
# Successfully installed aif360-0.5.0

# %% [markdown]
# # Import dataset before
#
# 0. Check the python version that are your virtual machine is using.
# 1. Switch from "Table of contents" to "File overview"
# 2. Move to /usr/local/lib/python3.10/dist-packages/aif360/data/raw/adult.
# 3. Put in the adult put the files: "adult.data", "adult.test", and "adult.names" attached to the notebook.
#
# ![image.png](data:image/png;base64,...)

# %%
# %matplotlib inline
# Load all necessary packages
import sys
sys.path.append("../")
from aif360.datasets import BinaryLabelDataset
from aif360.datasets import AdultDataset, GermanDataset, CompasDataset
from aif360.metrics import BinaryLabelDatasetMetric
from aif360.metrics import ClassificationMetric
from aif360.metrics.utils import compute_boolean_conditioning_vector

from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_adult, load_preproc_data_compas, load_preproc_data_german

from aif360.algorithms.inprocessing.adversarial_debiasing import AdversarialDebiasing

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn.metrics import accuracy_score

from IPython.display import Markdown, display
import matplotlib.pyplot as plt

import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

# %% [markdown]
# #### Load dataset and set options

# %%
# Get the dataset and split into train and test
dataset_orig = load_preproc_data_adult()

privileged_groups = [{'sex': 1}]
unprivileged_groups = [{'sex': 0}]

dataset_orig_train, dataset_orig_test = dataset_orig.split([0.7], shuffle=True)

# %%
# print out some labels, names, etc.
display(Markdown("#### Training Dataset shape"))
print(dataset_orig_train.features.shape)
display(Markdown("#### Favorable and unfavorable labels"))
print(dataset_orig_train.favorable_label, dataset_orig_train.unfavorable_label)
display(Markdown("#### Protected attribute names"))
print(dataset_orig_train.protected_attribute_names)
display(Markdown("#### Privileged and unprivileged protected attribute values"))
print(dataset_orig_train.privileged_protected_attributes, 
      dataset_orig_train.unprivileged_protected_attributes)
display(Markdown("#### Dataset feature names"))
print(dataset_orig_train.feature_names)
# Out:
# #### Training Dataset shape
# (34189, 18)
# #### Favorable and unfavorable labels
# 1.0 0.0
# #### Protected attribute names
# ['sex', 'race']
# #### Privileged and unprivileged protected attribute values
# [array([1.]), array([1.])] [array([0.]), array([0.])]
# #### Dataset feature names
# ['race', 'sex', 'Age (decade)=10', 'Age (decade)=20', 'Age (decade)=30', 'Age (decade)=40', 'Age (decade)=50', 'Age (decade)=60', 'Age (decade)=>=70', 'Education Years=6', 'Education Years=7', 'Education Years=8', 'Education Years=9', 'Education Years=10', 'Education Years=11', 'Education Years=12', 'Education Years=<6', 'Education Years=>12']

# %% [markdown]
# #### Metric for original training data

# %%
# Metric for the original dataset
metric_orig_train = BinaryLabelDatasetMetric(dataset_orig_train, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
display(Markdown("#### Original training dataset"))
print("Train set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_orig_train.mean_difference())
metric_orig_test = BinaryLabelDatasetMetric(dataset_orig_test, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)
print("Test set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_orig_test.mean_difference())
# Out:
# #### Original training dataset
# Train set: Difference in mean outcomes between unprivileged and privileged groups = -0.195739
# Test set: Difference in mean outcomes between unprivileged and privileged groups = -0.191646

# %%
min_max_scaler = MaxAbsScaler()
dataset_orig_train.features = min_max_scaler.fit_transform(dataset_orig_train.features)
dataset_orig_test.features = min_max_scaler.transform(dataset_orig_test.features)
metric_scaled_train = BinaryLabelDatasetMetric(dataset_orig_train, 
                             unprivileged_groups=unprivileged_groups,
                             privileged_groups=privileged_groups)
display(Markdown("#### Scaled dataset - Verify that the scaling does not affect the group label statistics"))
print("Train set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_scaled_train.mean_difference())
metric_scaled_test = BinaryLabelDatasetMetric(dataset_orig_test, 
                             unprivileged_groups=unprivileged_groups,
                             privileged_groups=privileged_groups)
print("Test set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_scaled_test.mean_difference())
# Out:
# #### Scaled dataset - Verify that the scaling does not affect the group label statistics
# Train set: Difference in mean outcomes between unprivileged and privileged groups = -0.195739
# Test set: Difference in mean outcomes between unprivileged and privileged groups = -0.191646

# %% [markdown]
# ### Learn plan classifier without debiasing

# %%
# Load post-processing algorithm that equalizes the odds
# Learn parameters with debias set to False
sess = tf.Session()
plain_model = AdversarialDebiasing(privileged_groups = privileged_groups,
                          unprivileged_groups = unprivileged_groups,
                          scope_name='plain_classifier',
                          debias=False,
                          sess=sess)

# %%
plain_model.fit(dataset_orig_train)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# epoch 0; iter: 0; batch classifier loss: 0.725570
# epoch 0; iter: 200; batch classifier loss: 0.483052
# epoch 1; iter: 0; batch classifier loss: 0.373634
# epoch 1; iter: 200; batch classifier loss: 0.379036
# epoch 2; iter: 0; batch classifier loss: 0.432353
# epoch 2; iter: 200; batch classifier loss: 0.414545
# epoch 3; iter: 0; batch classifier loss: 0.364648
# epoch 3; iter: 200; batch classifier loss: 0.489499
# epoch 4; iter: 0; batch classifier loss: 0.416176
# epoch 4; iter: 200; batch classifier loss: 0.418253
# epoch 5; iter: 0; batch classifier loss: 0.453349
# epoch 5; iter: 200; batch classifier loss: 0.467885
# epoch 6; iter: 0; batch classifier loss: 0.375787
# epoch 6; iter: 200; batch classifier loss: 0.410068
# epoch 7; iter: 0; batch classifier loss: 0.399629
# epoch 7; iter: 200; batch classifier loss: 0.451836
# epoch 8; iter: 0; batch classifier loss: 0.392029
# epoch 8; iter: 200; batch classifier loss: 0.377506
# epoch 9; iter: 0; batch classifier loss: 0.419210
# epoch 9; iter: 200; batch classifier loss: 0.400735
# epoch 10; iter: 0; batch classifier loss: 0.442266
# epoch 10; iter: 200; batch classifier loss: 0.369065
# epoch 40; iter: 0; batch classifier loss: 0.376255
# epoch 40; iter: 200; batch classifier loss: 0.397960
# epoch 41; iter: 0; batch classifier loss: 0.387210
# epoch 41; iter: 200; batch classifier loss: 0.433172
# epoch 42; iter: 0; batch classifier loss: 0.418906
# epoch 42; iter: 200; batch classifier loss: 0.403209
# epoch 43; iter: 0; batch classifier loss: 0.496266
# epoch 43; iter: 200; batch classifier loss: 0.405572
# epoch 44; iter: 0; batch classifier loss: 0.426438
# epoch 44; iter: 200; batch classifier loss: 0.351762
# epoch 45; iter: 0; batch classifier loss: 0.354397
# epoch 45; iter: 200; batch classifier loss: 0.420103
# epoch 46; iter: 0; batch classifier loss: 0.533745
# epoch 46; iter: 200; batch classifier loss: 0.394918
# epoch 47; iter: 0; batch classifier loss: 0.361266
# epoch 47; iter: 200; batch classifier loss: 0.502786
# epoch 48; iter: 0; batch classifier loss: 0.431318
# epoch 48; iter: 200; batch classifier loss: 0.467523
# epoch 49; iter: 0; batch classifier loss: 0.388736
# epoch 49; iter: 200; batch classifier loss: 0.417939

# %%
# Apply the plain model to test data
dataset_nodebiasing_train = plain_model.predict(dataset_orig_train)
dataset_nodebiasing_test = plain_model.predict(dataset_orig_test)

# %%
# Metrics for the dataset from plain model (without debiasing)
display(Markdown("#### Plain model - without debiasing - dataset metrics"))
metric_dataset_nodebiasing_train = BinaryLabelDatasetMetric(dataset_nodebiasing_train, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)

print("Train set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_nodebiasing_train.mean_difference())

metric_dataset_nodebiasing_test = BinaryLabelDatasetMetric(dataset_nodebiasing_test, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)

print("Test set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_nodebiasing_test.mean_difference())

display(Markdown("#### Plain model - without debiasing - classification metrics"))
classified_metric_nodebiasing_test = ClassificationMetric(dataset_orig_test, 
                                                 dataset_nodebiasing_test,
                                                 unprivileged_groups=unprivileged_groups,
                                                 privileged_groups=privileged_groups)
print("Test set: Classification accuracy = %f" % classified_metric_nodebiasing_test.accuracy())
TPR = classified_metric_nodebiasing_test.true_positive_rate()
TNR = classified_metric_nodebiasing_test.true_negative_rate()
bal_acc_nodebiasing_test = 0.5*(TPR+TNR)

#https://aif360.readthedocs.io/en/stable/modules/generated/aif360.metrics.ClassificationMetric.html#aif360.metrics.ClassificationMetric.true_positive_rate_difference
print("Test set: Balanced classification accuracy = %f" % bal_acc_nodebiasing_test)
print("Test set: Disparate impact = %f" % classified_metric_nodebiasing_test.disparate_impact())
print("Test set: Equal opportunity difference = %f" % classified_metric_nodebiasing_test.equal_opportunity_difference())
print("Test set: Average odds difference = %f" % classified_metric_nodebiasing_test.average_odds_difference())
print("Test set: Theil_index = %f" % classified_metric_nodebiasing_test.theil_index())
# Out:
# #### Plain model - without debiasing - dataset metrics
# Train set: Difference in mean outcomes between unprivileged and privileged groups = -0.208275
# Test set: Difference in mean outcomes between unprivileged and privileged groups = -0.208767
# #### Plain model - without debiasing - classification metrics
# Test set: Classification accuracy = 0.800519
# Test set: Balanced classification accuracy = 0.655606
# Test set: Disparate impact = 0.000000
# Test set: Equal opportunity difference = -0.444705
# Test set: Average odds difference = -0.275165
# Test set: Theil_index = 0.182434

# %% [markdown]
# ### Apply in-processing algorithm based on adversarial learning

# %%
sess.close()
tf.reset_default_graph()
sess = tf.Session()

# %%
# Learn parameters with debias set to True
debiased_model = AdversarialDebiasing(privileged_groups = privileged_groups,
                          unprivileged_groups = unprivileged_groups,
                          scope_name='debiased_classifier',
                          debias=True,
                          sess=sess)

# %%
debiased_model.fit(dataset_orig_train)
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.648035; batch adversarial loss: 0.740578
# epoch 0; iter: 200; batch classifier loss: 0.490718; batch adversarial loss: 0.665547
# epoch 1; iter: 0; batch classifier loss: 0.393891; batch adversarial loss: 0.650329
# epoch 1; iter: 200; batch classifier loss: 0.475083; batch adversarial loss: 0.648407
# epoch 2; iter: 0; batch classifier loss: 0.503714; batch adversarial loss: 0.628893
# epoch 2; iter: 200; batch classifier loss: 0.485817; batch adversarial loss: 0.577151
# epoch 3; iter: 0; batch classifier loss: 0.567167; batch adversarial loss: 0.628641
# epoch 3; iter: 200; batch classifier loss: 0.505468; batch adversarial loss: 0.619009
# epoch 4; iter: 0; batch classifier loss: 0.518289; batch adversarial loss: 0.608031
# epoch 4; iter: 200; batch classifier loss: 0.466263; batch adversarial loss: 0.674348
# epoch 5; iter: 0; batch classifier loss: 0.368220; batch adversarial loss: 0.621429
# epoch 5; iter: 200; batch classifier loss: 0.446006; batch adversarial loss: 0.609406
# epoch 6; iter: 0; batch classifier loss: 0.384127; batch adversarial loss: 0.611475
# epoch 6; iter: 200; batch classifier loss: 0.394998; batch adversarial loss: 0.650914
# epoch 7; iter: 0; batch classifier loss: 0.493680; batch adversarial loss: 0.594920
# epoch 7; iter: 200; batch classifier loss: 0.302873; batch adversarial loss: 0.582037
# epoch 8; iter: 0; batch classifier loss: 0.496426; batch adversarial loss: 0.583660
# epoch 8; iter: 200; batch classifier loss: 0.410478; batch adversarial loss: 0.626199
# epoch 9; iter: 0; batch classifier loss: 0.381486; batch adversarial loss: 0.624402
# epoch 9; iter: 200; batch classifier loss: 0.482919; batch adversarial loss: 0.555145
# epoch 10; iter: 0; batch classifier loss: 0.489297; batch adversarial loss: 0.577954
# epoch 10; iter: 200; batch classifier loss: 0.368789; batch adversarial loss: 0.578418
# epoch 11; iter: 0; batch classifier loss: 0.367955; batch adversarial loss: 0.647671
# epoch 11; iter: 200; batch classifier loss: 0.489942; batch adversarial loss: 0.585842
# epoch 12; iter: 0; batch classifier loss: 0.427047; batch adversarial loss: 0.646402
# epoch 12; iter: 200; batch classifier loss: 0.421247; batch adversarial loss: 0.598761
# epoch 13; iter: 0; batch classifier loss: 0.491686; batch adversarial loss: 0.606419
# epoch 13; iter: 200; batch classifier loss: 0.434025; batch adversarial loss: 0.647425
# epoch 14; iter: 0; batch classifier loss: 0.416697; batch adversarial loss: 0.572316
# epoch 14; iter: 200; batch classifier loss: 0.519243; batch adversarial loss: 0.692873
# epoch 15; iter: 0; batch classifier loss: 0.430484; batch adversarial loss: 0.608545
# epoch 34; iter: 0; batch classifier loss: 0.411260; batch adversarial loss: 0.579809
# epoch 34; iter: 200; batch classifier loss: 0.508858; batch adversarial loss: 0.632356
# epoch 35; iter: 0; batch classifier loss: 0.414986; batch adversarial loss: 0.603172
# epoch 35; iter: 200; batch classifier loss: 0.402393; batch adversarial loss: 0.574401
# epoch 36; iter: 0; batch classifier loss: 0.412457; batch adversarial loss: 0.549730
# epoch 36; iter: 200; batch classifier loss: 0.418093; batch adversarial loss: 0.530689
# epoch 37; iter: 0; batch classifier loss: 0.379351; batch adversarial loss: 0.546435
# epoch 37; iter: 200; batch classifier loss: 0.381422; batch adversarial loss: 0.605451
# epoch 38; iter: 0; batch classifier loss: 0.347835; batch adversarial loss: 0.605037
# epoch 38; iter: 200; batch classifier loss: 0.432108; batch adversarial loss: 0.610366
# epoch 39; iter: 0; batch classifier loss: 0.416022; batch adversarial loss: 0.622534
# epoch 39; iter: 200; batch classifier loss: 0.437154; batch adversarial loss: 0.643620
# epoch 40; iter: 0; batch classifier loss: 0.457946; batch adversarial loss: 0.541434
# epoch 40; iter: 200; batch classifier loss: 0.505134; batch adversarial loss: 0.638148
# epoch 41; iter: 0; batch classifier loss: 0.460574; batch adversarial loss: 0.604809
# epoch 41; iter: 200; batch classifier loss: 0.393431; batch adversarial loss: 0.642110
# epoch 42; iter: 0; batch classifier loss: 0.352485; batch adversarial loss: 0.681232
# epoch 42; iter: 200; batch classifier loss: 0.465686; batch adversarial loss: 0.589688
# epoch 43; iter: 0; batch classifier loss: 0.463614; batch adversarial loss: 0.610055
# epoch 43; iter: 200; batch classifier loss: 0.405541; batch adversarial loss: 0.592175
# epoch 44; iter: 0; batch classifier loss: 0.446419; batch adversarial loss: 0.585329
# epoch 44; iter: 200; batch classifier loss: 0.416545; batch adversarial loss: 0.584804
# epoch 45; iter: 0; batch classifier loss: 0.416113; batch adversarial loss: 0.614752
# epoch 45; iter: 200; batch classifier loss: 0.417769; batch adversarial loss: 0.609707
# epoch 46; iter: 0; batch classifier loss: 0.465485; batch adversarial loss: 0.638299
# epoch 46; iter: 200; batch classifier loss: 0.473716; batch adversarial loss: 0.620119
# epoch 47; iter: 0; batch classifier loss: 0.401848; batch adversarial loss: 0.606417
# epoch 47; iter: 200; batch classifier loss: 0.418821; batch adversarial loss: 0.593410
# epoch 48; iter: 0; batch classifier loss: 0.498810; batch adversarial loss: 0.547535
# epoch 48; iter: 200; batch classifier loss: 0.376122; batch adversarial loss: 0.580477
# epoch 49; iter: 0; batch classifier loss: 0.418102; batch adversarial loss: 0.606482
# epoch 49; iter: 200; batch classifier loss: 0.500164; batch adversarial loss: 0.576488

# %%
# Apply the plain model to test data
dataset_debiasing_train = debiased_model.predict(dataset_orig_train)
dataset_debiasing_test = debiased_model.predict(dataset_orig_test)

# %%
# Metrics for the dataset from plain model (without debiasing)
display(Markdown("#### Plain model - without debiasing - dataset metrics"))
print("Train set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_nodebiasing_train.mean_difference())
print("Test set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_nodebiasing_test.mean_difference())

# Metrics for the dataset from model with debiasing
display(Markdown("#### Model - with debiasing - dataset metrics"))
metric_dataset_debiasing_train = BinaryLabelDatasetMetric(dataset_debiasing_train, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)

print("Train set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_debiasing_train.mean_difference())

metric_dataset_debiasing_test = BinaryLabelDatasetMetric(dataset_debiasing_test, 
                                             unprivileged_groups=unprivileged_groups,
                                             privileged_groups=privileged_groups)

print("Test set: Difference in mean outcomes between unprivileged and privileged groups = %f" % metric_dataset_debiasing_test.mean_difference())



display(Markdown("#### Plain model - without debiasing - classification metrics"))
print("Test set: Classification accuracy = %f" % classified_metric_nodebiasing_test.accuracy())
TPR = classified_metric_nodebiasing_test.true_positive_rate()
TNR = classified_metric_nodebiasing_test.true_negative_rate()
bal_acc_nodebiasing_test = 0.5*(TPR+TNR)
print("Test set: Balanced classification accuracy = %f" % bal_acc_nodebiasing_test)
print("Test set: Disparate impact = %f" % classified_metric_nodebiasing_test.disparate_impact())
print("Test set: Equal opportunity difference = %f" % classified_metric_nodebiasing_test.equal_opportunity_difference())
print("Test set: Average odds difference = %f" % classified_metric_nodebiasing_test.average_odds_difference())
print("Test set: Theil_index = %f" % classified_metric_nodebiasing_test.theil_index())



display(Markdown("#### Model - with debiasing - classification metrics"))
classified_metric_debiasing_test = ClassificationMetric(dataset_orig_test, 
                                                 dataset_debiasing_test,
                                                 unprivileged_groups=unprivileged_groups,
                                                 privileged_groups=privileged_groups)
print("Test set: Classification accuracy = %f" % classified_metric_debiasing_test.accuracy())
TPR = classified_metric_debiasing_test.true_positive_rate()
TNR = classified_metric_debiasing_test.true_negative_rate()
bal_acc_debiasing_test = 0.5*(TPR+TNR)
print("Test set: Balanced classification accuracy = %f" % bal_acc_debiasing_test)
print("Test set: Disparate impact = %f" % classified_metric_debiasing_test.disparate_impact())
print("Test set: Equal opportunity difference = %f" % classified_metric_debiasing_test.equal_opportunity_difference())
print("Test set: Average odds difference = %f" % classified_metric_debiasing_test.average_odds_difference())
print("Test set: Theil_index = %f" % classified_metric_debiasing_test.theil_index())
# Out:
# #### Plain model - without debiasing - dataset metrics
# Train set: Difference in mean outcomes between unprivileged and privileged groups = -0.208275
# Test set: Difference in mean outcomes between unprivileged and privileged groups = -0.208767
# #### Model - with debiasing - dataset metrics
# Train set: Difference in mean outcomes between unprivileged and privileged groups = -0.077576
# Test set: Difference in mean outcomes between unprivileged and privileged groups = -0.076860
# #### Plain model - without debiasing - classification metrics
# Test set: Classification accuracy = 0.800519
# Test set: Balanced classification accuracy = 0.655606
# Test set: Disparate impact = 0.000000
# Test set: Equal opportunity difference = -0.444705
# Test set: Average odds difference = -0.275165
# Test set: Theil_index = 0.182434
# #### Model - with debiasing - classification metrics
# Test set: Classification accuracy = 0.788576
# Test set: Balanced classification accuracy = 0.668151
# Test set: Disparate impact = 0.626734
# Test set: Equal opportunity difference = -0.020659
# Test set: Average odds difference = -0.016152
# Test set: Theil_index = 0.173681

# %% [markdown]
#     References:
#     [1] B. H. Zhang, B. Lemoine, and M. Mitchell, "Mitigating UnwantedBiases with Adversarial Learning,"
#     AAAI/ACM Conference on Artificial Intelligence, Ethics, and Society, 2018.
